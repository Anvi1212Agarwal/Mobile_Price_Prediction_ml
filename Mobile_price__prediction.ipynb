# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
import zipfile

with zipfile.ZipFile('/content/Mobile_Price_ml.zip', 'r') as z:
    with z.open('train.csv') as f:
        df = pd.read_csv(f)

display(df.head())
# Out:
#    battery_power  blue  clock_speed  ...  touch_screen  wifi  price_range
# 0            842     0          2.2  ...             0     1            1
# 1           1021     1          0.5  ...             1     0            2
# 2            563     1          0.5  ...             1     0            2
# 3            615     1          2.5  ...             0     0            2
# 4           1821     1          1.2  ...             1     0            1
#
# [5 rows x 21 columns]

# %%
df.head()
# Out:
#    battery_power  blue  clock_speed  ...  touch_screen  wifi  price_range
# 0            842     0          2.2  ...             0     1            1
# 1           1021     1          0.5  ...             1     0            2
# 2            563     1          0.5  ...             1     0            2
# 3            615     1          2.5  ...             0     0            2
# 4           1821     1          1.2  ...             1     0            1
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (2000, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#        battery_power       blue  ...         wifi  price_range
# count    2000.000000  2000.0000  ...  2000.000000  2000.000000
# mean     1238.518500     0.4950  ...     0.507000     1.500000
# std       439.418206     0.5001  ...     0.500076     1.118314
# min       501.000000     0.0000  ...     0.000000     0.000000
# 25%       851.750000     0.0000  ...     0.000000     0.750000
# 50%      1226.000000     0.0000  ...     1.000000     1.500000
# 75%      1615.250000     1.0000  ...     1.000000     2.250000
# max      1998.000000     1.0000  ...     1.000000     3.000000
#
# [8 rows x 21 columns]

# %%
corr = df.corr()

# %%
sns.heatmap(corr, annot=True, fmt=".2f",
 linewidths=.5,       # Add thin lines between cells for better visual separation.
    linecolor='black',   # Color of the separator lines.
    cbar_kws={'shrink': 0.7}, # Adjust color bar size if it's too large or small.
    # --- This is the key adjustment for text size inside cells ---
    annot_kws={"size": 6} )
figure_size=(14,17)
plt.show()

# %%
df = df.drop(['n_cores', 'm_dep'], axis=1)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
X = df.drop('price_range', axis=1) # All features except the target
Y = df['price_range']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, mean_squared_error

models = {
    'lg':LogisticRegression(max_iter=1000),
    'rfg':RandomForestRegressor(),
    'rfc':RandomForestClassifier()}

# %%
from sklearn.metrics import accuracy_score, mean_squared_error

for name,model in models.items():
    model.fit(X_train,Y_train)
    Ypred = model.predict(X_test)
    if name == 'lg':
        print(f"{name} with accuracy : {accuracy_score(Y_test,Ypred)} ")
    elif name == 'rfg':
        print(f"{name} with Mean Squared Error : {mean_squared_error(Y_test,Ypred)} ")
    elif name == 'rfc':
          print(f"{name} with accuracy : {accuracy_score(Y_test,Ypred)} ")
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# lg with accuracy : 0.7
# rfg with Mean Squared Error : 0.07121725
# rfc with accuracy : 0.8875

# %%
rfc = RandomForestClassifier()
rfc.fit(X_train,Y_train)
Ypred = model.predict(X_test)

# %%
#prediction system
